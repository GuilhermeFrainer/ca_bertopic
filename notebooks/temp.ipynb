# %%
import polars as pl

# %%
lf = pl.scan_parquet("../data/processed/trump_embeddings.parquet")
lf = lf.drop("id").with_row_index()
lf.head().collect()

# %%
lf.sink_parquet("../data/processed/trump_embeddings_2.parquet")

# %%
lf = pl.scan_parquet("../data/processed/trump_embeddings_2.parquet")
lf.head().collect()

# %%
lf.select(pl.len()).collect()
